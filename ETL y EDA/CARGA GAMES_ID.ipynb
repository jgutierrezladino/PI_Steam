# %% [markdown]
#  ### Cargamos los datos del archivo games

# %%
import pandas as pd
import gzip
import json

# %%
steam_games = "../DataSets/steam_games.json.gz"

# %%
datos_games = []
with gzip.open(steam_games, 'rt', encoding='utf-8') as archivo_games:
    for linea in archivo_games:
        diccionario_linea_games = json.loads(linea)
        datos_games.append(diccionario_linea_games)
df_games = pd.DataFrame(datos_games)
df_games.head()
# Out:
#   publisher genres app_name title  url release_date tags reviews_url specs  \
# 0       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN   NaN
# 1       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN   NaN
# 2       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN   NaN
# 3       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN   NaN
# 4       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN   NaN
#
#   price early_access   id developer
# 0   NaN          NaN  NaN       NaN
# 1   NaN          NaN  NaN       NaN
# 2   NaN          NaN  NaN       NaN
# 3   NaN          NaN  NaN       NaN
# 4   NaN          NaN  NaN       NaN

# %%
columnas_deseadas = ['id', 'genres', 'app_name', 'release_date']
df_games = df_games[columnas_deseadas]

# %%
df_games = df_games.dropna()

# %%
df_games_desa = df_games.explode('genres')

# %%
df_desanidado = df_games_desa.reset_index(drop=True)

# %%
df_sampled = df_desanidado.sample(frac=0.1, random_state=42)
df_sampled.to_csv('../DataSets/df_games_id.csv',index=False)

# %%
df_sampled
# Out:
#            id                     genres  \
# 23662  683570                  Adventure
# 31544  585900                  Adventure
# 62163  297270                   Strategy
# 64347  321182  Design &amp; Illustration
# 21261  614910                     Casual
# ...       ...                        ...
# 12141  236870                     Action
# 57222  378474                     Action
# 277     19200                     Action
# 5510   325180          Software Training
# 5740   207140                      Indie
#
#                                     app_name release_date
# 23662               Cludbugz's Twisted Magic   2017-08-04
# 31544            Harvest Moon: Light of Hope   2017-11-14
# 62163          Exodus Wars: Fractured Empire   2015-01-30
# 64347  RPG Maker VX Ace - Dungeon Music Pack   2014-09-16
# 21261                          #monstercakes   2017-05-05
# ...                                      ...          ...
# ...
